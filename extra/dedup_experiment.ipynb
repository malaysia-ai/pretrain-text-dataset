# %% [markdown]
# ## Remove Duplicate in your dataset

# %%
import json
from datasets import Dataset
import pandas as pd

# %% [markdown]
# ### 1. Convert dataset into huggingface type dataset
#
# - column to dedupe must be text type

# %%
with open("/home/ubuntu/aisyah/dedupe_test2.jsonl") as fopen:
    data = [json.loads(line) for line in fopen]

# %%
data[0]
# Out:
# {'id': 0,
#  'text': 'SELEPAS seminggu politik negara kecoh pada Februari 2020, Muhyiddin Yassin mengangkat sumpah sebagai perdana menteri pada 1 Mac susulan peletakan jawatan Dr Mahathir Mohamed dan keruntuhan kerajaan Pakatan Harapan (PH). Sepanjang memegang jawatan itu selama 16 bulan, kerajaannya yang terbentuk bersama bekas musuhnya yang kemudian menjadi sekutu, berdepan jatuh bangun, turun dan naik, terutama dalam mengendalikan pandemik Covid-19. Muhyiddin meletak jawatan perdana menteri hari ini selepas hilang majoriti di Dewan Rakyat apabila 15 ahli Parlimen Umno menarik balik sokongan. Presiden Bersatu itu pada awalnya enggan meletak jawatan, tetapi cubaan terakhirnya menghulurkan tawaran kerjasama kepada pembangkang pada Jumaat gagal, apabila semua parti pembangkang menolaknya. Muhyiddin atau mesra dengan jolokan panggilan “Abah” oleh netizen, akan menjadi perdana menteri sementara bermula hari ini hingga pelantikan baharu dibuat, menurut kenyataan Istana Negara. – 16 Ogos, 2021.'}

# %%
len(data)
# Out:
# 473487

# %%
data_dict = {
    key: [entry[key] for entry in data]
    for key in data[0]  # Assuming all dictionaries have the same keys
}

# %%
dataset = Dataset.from_dict(data_dict)

# %%
dataset
# Out:
# Dataset({
#     features: ['id', 'text'],
#     num_rows: 473487
# })

# %%
dataset.save_to_disk("text_dedup/test-1")
# Out:
# Saving the dataset (0/2 shards):   0%|          | 0/473487 [00:00<?, ? examples/s]

# %% [markdown]
# ### 2. Run below command
#
# make sure directory for the script is correct before running the command
#
# - path -  your dataset to dedupe path
# - name - relevant only when u use dataset directly from huggingface
# - output - output directory of the dedupe dataset
# - column - column of the text we are going to remove duplicate
# - threshold - jaccard similarity threshold
# - local - (local dataset or directly from huggingface) remove if dataset is not local

# %%
# !python3 -m text_dedup.minhash \
  --path "text_dedup/test-1" \
  --split "train" \
  --cache_dir "./cache" \
  --output "MinHash_Output/Dedup_Dataset_Trial-0" \
  --column "text" \
  --batch_size 10000 \
  --threshold 0.95 \
  --local

#ngram default = 5, threshold jaccard similarity = 0.7
# Out:
# Iterating MinHashes...: 100%|███████████████████| 48/48 [00:05<00:00,  8.47it/s]
# Clustering...: 100%|██████████████████████████████| 5/5 [00:00<00:00, 20.13it/s]
# Duplicate pairs before filtering:
# Cluster 126 has duplicate pairs: [126, 470431]
# Cluster 195 has duplicate pairs: [195, 450632]
# Cluster 484 has duplicate pairs: [484, 448413]
# Cluster 746 has duplicate pairs: [746, 367517]
# Cluster 1014 has duplicate pairs: [1014, 344772]
# Cluster 1294 has duplicate pairs: [1294, 468601]
# Cluster 1296 has duplicate pairs: [1296, 315917]
# Cluster 1298 has duplicate pairs: [1298, 462415]
# Cluster 1337 has duplicate pairs: [1337, 433726]
# Cluster 1486 has duplicate pairs: [1486, 396912]
# Cluster 1787 has duplicate pairs: [1787, 457257]
# Cluster 1794 has duplicate pairs: [1794, 358727]
# Cluster 1822 has duplicate pairs: [1822, 409252]
# Cluster 1998 has duplicate pairs: [1998, 322529]
# Cluster 2105 has duplicate pairs: [2105, 417868]
# Cluster 2143 has duplicate pairs: [2143, 385378]
# Cluster 2333 has duplicate pairs: [2333, 301327]
# Cluster 2353 has duplicate pairs: [2353, 453168]
# Cluster 3002 has duplicate pairs: [3002, 303473]
# Cluster 3043 has duplicate pairs: [3043, 443233]
# Cluster 3124 has duplicate pairs: [3124, 357290]
# Cluster 3139 has duplicate pairs: [3139, 345280]
# Cluster 3183 has duplicate pairs: [3183, 447743]
# Cluster 3258 has duplicate pairs: [3258, 442708]
# Cluster 3416 has duplicate pairs: [3416, 336660]
# Cluster 4087 has duplicate pairs: [4087, 357938]
# Cluster 4151 has duplicate pairs: [4151, 448060]
# Cluster 4189 has duplicate pairs: [4189, 4867]
# Cluster 4688 has duplicate pairs: [4688, 303191]
# Cluster 4902 has duplicate pairs: [4902, 322491]
# Cluster 5162 has duplicate pairs: [5162, 412475]
# Cluster 5426 has duplicate pairs: [5426, 407733]
# Cluster 5901 has duplicate pairs: [5901, 419331]
# Cluster 6006 has duplicate pairs: [6006, 435005]
# Cluster 6040 has duplicate pairs: [6040, 374774]
# Cluster 6150 has duplicate pairs: [6150, 440755]
# Cluster 6269 has duplicate pairs: [6269, 439609]
# Cluster 6662 has duplicate pairs: [6662, 357667]
# Cluster 6832 has duplicate pairs: [6832, 404252]
# Cluster 6879 has duplicate pairs: [6879, 396837]
# Cluster 7115 has duplicate pairs: [7115, 343693]
# Cluster 7279 has duplicate pairs: [7279, 362800]
# Cluster 7307 has duplicate pairs: [7307, 425938]
# Cluster 7396 has duplicate pairs: [7396, 312175]
# Cluster 7700 has duplicate pairs: [7700, 330291]
# Cluster 7997 has duplicate pairs: [7997, 469016]
# Cluster 8098 has duplicate pairs: [8098, 333761]
# Cluster 8726 has duplicate pairs: [8726, 376008]
# Cluster 8943 has duplicate pairs: [8943, 319472]
# Cluster 9265 has duplicate pairs: [9265, 402953]
# Cluster 9404 has duplicate pairs: [9404, 316776]
# Cluster 9603 has duplicate pairs: [9603, 434432]
# Cluster 9633 has duplicate pairs: [9633, 299248]
# Cluster 9892 has duplicate pairs: [9892, 428494]
# Cluster 10251 has duplicate pairs: [10251, 360476]
# Cluster 10541 has duplicate pairs: [10541, 306863]
# Cluster 10625 has duplicate pairs: [10625, 318004]
# Cluster 10927 has duplicate pairs: [10927, 432976]
# Cluster 10933 has duplicate pairs: [10933, 423987]
# Cluster 11044 has duplicate pairs: [11044, 381456]
# Cluster 11066 has duplicate pairs: [11066, 360682]
# Cluster 11526 has duplicate pairs: [11526, 465698]
# Cluster 11736 has duplicate pairs: [11736, 378855]
# Cluster 11789 has duplicate pairs: [11789, 472513]
# Cluster 12305 has duplicate pairs: [12305, 346813]
# Cluster 12361 has duplicate pairs: [12361, 324000]
# Cluster 12594 has duplicate pairs: [12594, 356281]
# Cluster 13033 has duplicate pairs: [13033, 291707]
# Cluster 13265 has duplicate pairs: [13265, 439290]
# Cluster 13269 has duplicate pairs: [13269, 312066]
# Cluster 13573 has duplicate pairs: [13573, 304087]
# Cluster 14188 has duplicate pairs: [14188, 448062]
# Cluster 14373 has duplicate pairs: [14373, 462045]
# Cluster 14623 has duplicate pairs: [14623, 427497]
# Cluster 15209 has duplicate pairs: [15209, 283189]
# Cluster 15232 has duplicate pairs: [15232, 293116]
# Cluster 15740 has duplicate pairs: [15740, 425674]
# Cluster 16023 has duplicate pairs: [16023, 257596, 270384]
# Cluster 19266 has duplicate pairs: [19266, 19267]
# Cluster 25616 has duplicate pairs: [25616, 25623]
# Cluster 34258 has duplicate pairs: [34258, 34264]
# Cluster 35822 has duplicate pairs: [35822, 35842]
# Cluster 36322 has duplicate pairs: [36322, 42904]
# Cluster 43898 has duplicate pairs: [43898, 47378, 54766, 57045, 58239, 69798, 76412, 76894, 78281, 81170, 88783, 90470, 92200, 94785, 97210, 97609, 100278, 102654, 103887, 120024, 124089, 139056, 149627, 152668, 152763, 160543, 186113, 188860, 191172, 191526, 193186, 196091, 197844, 200823, 223297, 286561, 289621, 296423, 299777, 300384, 325820, 334026, 363986, 410539, 421438, 440267]
# Cluster 44285 has duplicate pairs: [44285, 44286]
# Cluster 45564 has duplicate pairs: [45564, 45817]
# Cluster 46547 has duplicate pairs: [46547, 54153]
# Cluster 47944 has duplicate pairs: [47944, 47982]
# Cluster 48526 has duplicate pairs: [48526, 48591]
# Cluster 51744 has duplicate pairs: [51744, 51787]
# Cluster 55479 has duplicate pairs: [55479, 55480]
# Cluster 58231 has duplicate pairs: [58231, 58243]
# Cluster 59092 has duplicate pairs: [59092, 59258]
# Cluster 60258 has duplicate pairs: [60258, 60635]
# Cluster 61536 has duplicate pairs: [61536, 62091]
# Cluster 62625 has duplicate pairs: [62625, 62627]
# Cluster 68077 has duplicate pairs: [68077, 68131]
# Cluster 69723 has duplicate pairs: [69723, 69790]
# Cluster 74880 has duplicate pairs: [74880, 75372]
# Cluster 75026 has duplicate pairs: [75026, 204252]
# Cluster 77639 has duplicate pairs: [77639, 77652]
# Cluster 83102 has duplicate pairs: [83102, 83267]
# Cluster 83362 has duplicate pairs: [83362, 83447]
# Cluster 84317 has duplicate pairs: [84317, 84336]
# Cluster 84949 has duplicate pairs: [84949, 85114]
# Cluster 91571 has duplicate pairs: [91571, 91762]
# Cluster 91611 has duplicate pairs: [91611, 91885]
# Cluster 91765 has duplicate pairs: [91765, 92472]
# Cluster 91917 has duplicate pairs: [91917, 91918]
# Cluster 94874 has duplicate pairs: [94874, 219161]
# Cluster 97238 has duplicate pairs: [97238, 97239]
# Cluster 100459 has duplicate pairs: [100459, 100466]
# Cluster 101736 has duplicate pairs: [101736, 101904]
# Cluster 103548 has duplicate pairs: [103548, 103624]
# Cluster 103957 has duplicate pairs: [103957, 104120]
# Cluster 108405 has duplicate pairs: [108405, 229683]
# Cluster 108905 has duplicate pairs: [108905, 108931]
# Cluster 113104 has duplicate pairs: [113104, 113653]
# Cluster 113656 has duplicate pairs: [113656, 113674]
# Cluster 113885 has duplicate pairs: [113885, 114018]
# Cluster 113891 has duplicate pairs: [113891, 113958, 114190]
# Cluster 115885 has duplicate pairs: [115885, 115911]
# Cluster 116769 has duplicate pairs: [116769, 116824]
# Cluster 119793 has duplicate pairs: [119793, 120228]
# Cluster 121724 has duplicate pairs: [121724, 121763]
# Cluster 129785 has duplicate pairs: [129785, 129794]
# Cluster 132250 has duplicate pairs: [132250, 132283]
# Cluster 133266 has duplicate pairs: [133266, 133273]
# Cluster 138473 has duplicate pairs: [138473, 138585]
# Cluster 148066 has duplicate pairs: [148066, 148068]
# Cluster 149035 has duplicate pairs: [149035, 149036]
# Cluster 154262 has duplicate pairs: [154262, 154305]
# Cluster 160882 has duplicate pairs: [160882, 160885]
# Cluster 164324 has duplicate pairs: [164324, 164325]
# Cluster 169785 has duplicate pairs: [169785, 169787]
# Cluster 169806 has duplicate pairs: [169806, 169814]
# Cluster 171504 has duplicate pairs: [171504, 171535]
# Cluster 174849 has duplicate pairs: [174849, 174878]
# Cluster 195629 has duplicate pairs: [195629, 195695]
# Cluster 196751 has duplicate pairs: [196751, 197339]
# Cluster 197317 has duplicate pairs: [197317, 197539]
# Cluster 203697 has duplicate pairs: [203697, 204539, 204563, 204887, 205168, 205176]
# Cluster 203851 has duplicate pairs: [203851, 203942]
# Cluster 211294 has duplicate pairs: [211294, 211295]
# Cluster 213095 has duplicate pairs: [213095, 307021]
# Cluster 213565 has duplicate pairs: [213565, 417531]
# Cluster 215047 has duplicate pairs: [215047, 363587]
# Cluster 215437 has duplicate pairs: [215437, 290376]
# Cluster 215442 has duplicate pairs: [215442, 282682]
# Cluster 215695 has duplicate pairs: [215695, 362018]
# Cluster 215778 has duplicate pairs: [215778, 457639]
# Cluster 215779 has duplicate pairs: [215779, 368739]
# Cluster 215824 has duplicate pairs: [215824, 216370]
# Cluster 215977 has duplicate pairs: [215977, 401340]
# Cluster 216522 has duplicate pairs: [216522, 306979]
# Cluster 216656 has duplicate pairs: [216656, 390074]
# Cluster 216900 has duplicate pairs: [216900, 217442]
# Cluster 217242 has duplicate pairs: [217242, 434107]
# Cluster 217823 has duplicate pairs: [217823, 442121]
# Cluster 218295 has duplicate pairs: [218295, 326400]
# Cluster 218296 has duplicate pairs: [218296, 340441]
# Cluster 218374 has duplicate pairs: [218374, 409869]
# Cluster 218771 has duplicate pairs: [218771, 402150]
# Cluster 219095 has duplicate pairs: [219095, 372548]
# Cluster 219218 has duplicate pairs: [219218, 326857]
# Cluster 219660 has duplicate pairs: [219660, 414158]
# Cluster 219889 has duplicate pairs: [219889, 401928]
# Cluster 219981 has duplicate pairs: [219981, 301357]
# Cluster 220955 has duplicate pairs: [220955, 396941]
# Cluster 220972 has duplicate pairs: [220972, 337792]
# Cluster 222689 has duplicate pairs: [222689, 222691]
# Cluster 223112 has duplicate pairs: [223112, 284581]
# Cluster 225973 has duplicate pairs: [225973, 469054]
# Cluster 227124 has duplicate pairs: [227124, 342346]
# Cluster 227601 has duplicate pairs: [227601, 227623]
# Cluster 229082 has duplicate pairs: [229082, 332097]
# Cluster 230598 has duplicate pairs: [230598, 392552]
# Cluster 230669 has duplicate pairs: [230669, 230677]
# Cluster 232544 has duplicate pairs: [232544, 383120]
# Cluster 232546 has duplicate pairs: [232546, 391469]
# Cluster 232788 has duplicate pairs: [232788, 232790]
# Cluster 232875 has duplicate pairs: [232875, 232879]
# Cluster 233026 has duplicate pairs: [233026, 233027]
# Cluster 233035 has duplicate pairs: [233035, 459341]
# Cluster 234599 has duplicate pairs: [234599, 234616]
# Cluster 234678 has duplicate pairs: [234678, 234688]
# Cluster 235064 has duplicate pairs: [235064, 235065]
# Cluster 235657 has duplicate pairs: [235657, 389846]
# Cluster 236871 has duplicate pairs: [236871, 437726]
# Cluster 238003 has duplicate pairs: [238003, 238004]
# Cluster 241283 has duplicate pairs: [241283, 246045]
# Cluster 241444 has duplicate pairs: [241444, 241620]
# Cluster 244699 has duplicate pairs: [244699, 244704]
# Cluster 248595 has duplicate pairs: [248595, 248917]
# Cluster 249566 has duplicate pairs: [249566, 250098]
# Cluster 249993 has duplicate pairs: [249993, 249996]
# Cluster 255965 has duplicate pairs: [255965, 255966]
# Cluster 262698 has duplicate pairs: [262698, 415049]
# Cluster 264489 has duplicate pairs: [264489, 264495]
# Cluster 270451 has duplicate pairs: [270451, 270452]
# Cluster 273377 has duplicate pairs: [273377, 273404]
# Cluster 274251 has duplicate pairs: [274251, 297491]
# Cluster 274343 has duplicate pairs: [274343, 390424]
# Cluster 274764 has duplicate pairs: [274764, 431844]
# Cluster 274901 has duplicate pairs: [274901, 399068]
# Cluster 274906 has duplicate pairs: [274906, 430670]
# Cluster 275099 has duplicate pairs: [275099, 383395]
# Cluster 276750 has duplicate pairs: [276750, 302274]
# Cluster 277086 has duplicate pairs: [277086, 277102]
# Cluster 277268 has duplicate pairs: [277268, 277278]
# Cluster 277971 has duplicate pairs: [277971, 288427]
# Cluster 278608 has duplicate pairs: [278608, 404675]
# Cluster 278883 has duplicate pairs: [278883, 469705]
# Cluster 278933 has duplicate pairs: [278933, 467772]
# Cluster 278938 has duplicate pairs: [278938, 332251]
# Cluster 279131 has duplicate pairs: [279131, 405505]
# Cluster 279718 has duplicate pairs: [279718, 424921]
# Cluster 279930 has duplicate pairs: [279930, 405323]
# Cluster 280123 has duplicate pairs: [280123, 404842]
# Cluster 280546 has duplicate pairs: [280546, 375173]
# Cluster 281653 has duplicate pairs: [281653, 405031]
# Cluster 281701 has duplicate pairs: [281701, 368979, 411824, 423632, 448984]
# Cluster 282746 has duplicate pairs: [282746, 355522]
# Cluster 283179 has duplicate pairs: [283179, 348620]
# Cluster 283572 has duplicate pairs: [283572, 469223]
# Cluster 283590 has duplicate pairs: [283590, 374881]
# Cluster 283767 has duplicate pairs: [283767, 285011, 289736, 289998, 290051, 290070, 294385, 301449, 304044, 304874, 305425, 305509, 306614, 307292, 310480, 311387, 312143, 312165, 313670, 316556, 318634, 320629, 323979, 325207, 326625, 327166, 327693, 328115, 328563, 328595, 331130, 332487, 333738, 336642, 337136, 338192, 340670, 341643, 347932, 349239, 353238, 356470, 365872, 369537, 369559, 369910, 369985, 370365, 371678, 372256, 380070, 385169, 385740, 386304, 386568, 390180, 392798, 393769, 394392, 395561, 395901, 397690, 402465, 402830, 403736, 403762, 404930, 405714, 406268, 409555, 410006, 410401, 410418, 410832, 410863, 414341, 417195, 417643, 418240, 419440, 420772, 420999, 424428, 425870, 428819, 428916, 429496, 431485, 432352, 432802, 434381, 434487, 434535, 435702, 441928, 442191, 443292, 443351, 445255, 446018, 448516, 448967, 451550, 452594, 456456, 456476, 456500, 459637, 462241, 466812, 471350, 472950]
# Cluster 283822 has duplicate pairs: [283822, 325576, 411071, 444366, 459319]
# Cluster 283890 has duplicate pairs: [283890, 401693]
# Cluster 284125 has duplicate pairs: [284125, 438373]
# Cluster 284324 has duplicate pairs: [284324, 378674]
# Cluster 284659 has duplicate pairs: [284659, 303591]
# Cluster 285594 has duplicate pairs: [285594, 382272]
# Cluster 286076 has duplicate pairs: [286076, 337873]
# Cluster 286199 has duplicate pairs: [286199, 386836]
# Cluster 286782 has duplicate pairs: [286782, 359773]
# Cluster 287414 has duplicate pairs: [287414, 465318]
# Cluster 287661 has duplicate pairs: [287661, 356350]
# Cluster 287893 has duplicate pairs: [287893, 425156]
# Cluster 287935 has duplicate pairs: [287935, 345190]
# Cluster 288409 has duplicate pairs: [288409, 352914]
# Cluster 288710 has duplicate pairs: [288710, 342659]
# Cluster 288750 has duplicate pairs: [288750, 359741]
# Cluster 289068 has duplicate pairs: [289068, 335858]
# Cluster 289459 has duplicate pairs: [289459, 412622]
# Cluster 290063 has duplicate pairs: [290063, 451688]
# Cluster 290448 has duplicate pairs: [290448, 296244]
# Cluster 290482 has duplicate pairs: [290482, 436377, 473183]
# Cluster 290900 has duplicate pairs: [290900, 291657]
# Cluster 291159 has duplicate pairs: [291159, 383950]
# Cluster 291689 has duplicate pairs: [291689, 344130]
# Cluster 292328 has duplicate pairs: [292328, 389100]
# Cluster 292433 has duplicate pairs: [292433, 353724]
# Cluster 292456 has duplicate pairs: [292456, 354642]
# Cluster 292655 has duplicate pairs: [292655, 408684]
# Cluster 293881 has duplicate pairs: [293881, 314336]
# Cluster 293950 has duplicate pairs: [293950, 372903, 382833, 420209, 441087]
# Cluster 294597 has duplicate pairs: [294597, 398885]
# Cluster 294720 has duplicate pairs: [294720, 359797]
# Cluster 294821 has duplicate pairs: [294821, 332400]
# Cluster 294868 has duplicate pairs: [294868, 463202]
# Cluster 295239 has duplicate pairs: [295239, 308381]
# Cluster 295264 has duplicate pairs: [295264, 458154]
# Cluster 295358 has duplicate pairs: [295358, 442022]
# Cluster 297487 has duplicate pairs: [297487, 470474]
# Cluster 298084 has duplicate pairs: [298084, 375867]
# Cluster 298186 has duplicate pairs: [298186, 386345]
# Cluster 298957 has duplicate pairs: [298957, 356141, 369156]
# Cluster 299216 has duplicate pairs: [299216, 386933]
# Cluster 299257 has duplicate pairs: [299257, 325380]
# Cluster 299859 has duplicate pairs: [299859, 454125]
# Cluster 300108 has duplicate pairs: [300108, 314220, 320738, 376405]
# Cluster 300192 has duplicate pairs: [300192, 345287]
# Cluster 300421 has duplicate pairs: [300421, 396816]
# Cluster 300558 has duplicate pairs: [300558, 332938]
# Cluster 301294 has duplicate pairs: [301294, 435679]
# Cluster 301920 has duplicate pairs: [301920, 353584]
# Cluster 302421 has duplicate pairs: [302421, 423354]
# Cluster 302756 has duplicate pairs: [302756, 374570]
# Cluster 303151 has duplicate pairs: [303151, 372526]
# Cluster 303812 has duplicate pairs: [303812, 370110]
# Cluster 304549 has duplicate pairs: [304549, 423448]
# Cluster 304995 has duplicate pairs: [304995, 470644]
# Cluster 305000 has duplicate pairs: [305000, 411323]
# Cluster 305045 has duplicate pairs: [305045, 451697]
# Cluster 305099 has duplicate pairs: [305099, 343384]
# Cluster 305454 has duplicate pairs: [305454, 368635, 468091]
# Cluster 306583 has duplicate pairs: [306583, 340775]
# Cluster 306831 has duplicate pairs: [306831, 395668]
# Cluster 307727 has duplicate pairs: [307727, 333831]
# Cluster 307907 has duplicate pairs: [307907, 361663, 457101]
# Cluster 307993 has duplicate pairs: [307993, 355374]
# Cluster 308180 has duplicate pairs: [308180, 350176]
# Cluster 308220 has duplicate pairs: [308220, 357662]
# Cluster 308345 has duplicate pairs: [308345, 440471]
# Cluster 309030 has duplicate pairs: [309030, 413959]
# Cluster 309190 has duplicate pairs: [309190, 359804]
# Cluster 309412 has duplicate pairs: [309412, 425728, 442419]
# Cluster 309635 has duplicate pairs: [309635, 336562]
# Cluster 310215 has duplicate pairs: [310215, 342010]
# Cluster 310473 has duplicate pairs: [310473, 387927]
# Cluster 310611 has duplicate pairs: [310611, 373544]
# Cluster 311912 has duplicate pairs: [311912, 408197]
# Cluster 312022 has duplicate pairs: [312022, 415171]
# Cluster 312629 has duplicate pairs: [312629, 324195]
# Cluster 313160 has duplicate pairs: [313160, 444659]
# Cluster 313723 has duplicate pairs: [313723, 378666]
# Cluster 314551 has duplicate pairs: [314551, 316312]
# Cluster 314767 has duplicate pairs: [314767, 453541]
# Cluster 315618 has duplicate pairs: [315618, 384595]
# Cluster 316158 has duplicate pairs: [316158, 397466]
# Cluster 316510 has duplicate pairs: [316510, 339250]
# Cluster 317486 has duplicate pairs: [317486, 370268]
# Cluster 318201 has duplicate pairs: [318201, 446216]
# Cluster 319226 has duplicate pairs: [319226, 343524]
# Cluster 320337 has duplicate pairs: [320337, 451339]
# Cluster 320577 has duplicate pairs: [320577, 420426]
# Cluster 320641 has duplicate pairs: [320641, 414022]
# Cluster 320721 has duplicate pairs: [320721, 331468, 396141]
# Cluster 321337 has duplicate pairs: [321337, 422162]
# Cluster 323001 has duplicate pairs: [323001, 410014]
# Cluster 323842 has duplicate pairs: [323842, 373638]
# Cluster 324934 has duplicate pairs: [324934, 350298]
# Cluster 325143 has duplicate pairs: [325143, 334802]
# Cluster 325429 has duplicate pairs: [325429, 421200]
# Cluster 326607 has duplicate pairs: [326607, 345477]
# Cluster 327170 has duplicate pairs: [327170, 350703]
# Cluster 327811 has duplicate pairs: [327811, 381660]
# Cluster 328023 has duplicate pairs: [328023, 386127]
# Cluster 328219 has duplicate pairs: [328219, 372248]
# Cluster 329042 has duplicate pairs: [329042, 388770]
# Cluster 329299 has duplicate pairs: [329299, 375837]
# Cluster 329593 has duplicate pairs: [329593, 347902]
# Cluster 329640 has duplicate pairs: [329640, 357270]
# Cluster 329877 has duplicate pairs: [329877, 402831]
# Cluster 330368 has duplicate pairs: [330368, 335659]
# Cluster 330694 has duplicate pairs: [330694, 464891]
# Cluster 331699 has duplicate pairs: [331699, 437895]
# Cluster 332329 has duplicate pairs: [332329, 407340]
# Cluster 332337 has duplicate pairs: [332337, 438118]
# Cluster 333203 has duplicate pairs: [333203, 416766]
# Cluster 333496 has duplicate pairs: [333496, 357631]
# Cluster 333768 has duplicate pairs: [333768, 377755]
# Cluster 335356 has duplicate pairs: [335356, 354860]
# Cluster 335432 has duplicate pairs: [335432, 416967]
# Cluster 335655 has duplicate pairs: [335655, 353869]
# Cluster 336019 has duplicate pairs: [336019, 459533]
# Cluster 336126 has duplicate pairs: [336126, 399903]
# Cluster 336473 has duplicate pairs: [336473, 422609]
# Cluster 336769 has duplicate pairs: [336769, 404409]
# Cluster 337797 has duplicate pairs: [337797, 374191]
# Cluster 338164 has duplicate pairs: [338164, 369589]
# Cluster 338417 has duplicate pairs: [338417, 396839]
# Cluster 338938 has duplicate pairs: [338938, 465848]
# Cluster 341709 has duplicate pairs: [341709, 445877]
# Cluster 342160 has duplicate pairs: [342160, 433701]
# Cluster 342174 has duplicate pairs: [342174, 415218]
# Cluster 342450 has duplicate pairs: [342450, 399205, 416272]
# Cluster 343598 has duplicate pairs: [343598, 465022]
# Cluster 344485 has duplicate pairs: [344485, 367297]
# Cluster 344487 has duplicate pairs: [344487, 357676]
# Cluster 345207 has duplicate pairs: [345207, 455803]
# Cluster 345275 has duplicate pairs: [345275, 363007]
# Cluster 345300 has duplicate pairs: [345300, 348715, 403735, 413724]
# Cluster 345661 has duplicate pairs: [345661, 349037]
# Cluster 345833 has duplicate pairs: [345833, 384106]
# Cluster 346454 has duplicate pairs: [346454, 365201]
# Cluster 347076 has duplicate pairs: [347076, 364484]
# Cluster 347498 has duplicate pairs: [347498, 460136]
# Cluster 347524 has duplicate pairs: [347524, 456198]
# Cluster 347967 has duplicate pairs: [347967, 401862]
# Cluster 349201 has duplicate pairs: [349201, 434231]
# Cluster 349208 has duplicate pairs: [349208, 432371]
# Cluster 349304 has duplicate pairs: [349304, 409656]
# Cluster 349384 has duplicate pairs: [349384, 396708]
# Cluster 349728 has duplicate pairs: [349728, 405572]
# Cluster 350574 has duplicate pairs: [350574, 380926]
# Cluster 350749 has duplicate pairs: [350749, 393500]
# Cluster 351149 has duplicate pairs: [351149, 448844]
# Cluster 351849 has duplicate pairs: [351849, 363580]
# Cluster 352287 has duplicate pairs: [352287, 375808]
# Cluster 352867 has duplicate pairs: [352867, 452615]
# Cluster 352873 has duplicate pairs: [352873, 394600]
# Cluster 352962 has duplicate pairs: [352962, 435424]
# Cluster 353429 has duplicate pairs: [353429, 354882]
# Cluster 355364 has duplicate pairs: [355364, 379488, 405125]
# Cluster 355979 has duplicate pairs: [355979, 443342]
# Cluster 356543 has duplicate pairs: [356543, 367421]
# Cluster 358429 has duplicate pairs: [358429, 429279]
# Cluster 358803 has duplicate pairs: [358803, 428107]
# Cluster 359060 has duplicate pairs: [359060, 444115]
# Cluster 359451 has duplicate pairs: [359451, 360710]
# Cluster 359814 has duplicate pairs: [359814, 398112]
# Cluster 359928 has duplicate pairs: [359928, 453034]
# Cluster 360769 has duplicate pairs: [360769, 379053]
# Cluster 361089 has duplicate pairs: [361089, 399072]
# Cluster 361948 has duplicate pairs: [361948, 433010]
# Cluster 363636 has duplicate pairs: [363636, 413929]
# Cluster 364103 has duplicate pairs: [364103, 409828]
# Cluster 365295 has duplicate pairs: [365295, 367588]
# Cluster 365360 has duplicate pairs: [365360, 408487]
# Cluster 365567 has duplicate pairs: [365567, 432648]
# Cluster 365908 has duplicate pairs: [365908, 432138]
# Cluster 367870 has duplicate pairs: [367870, 373102]
# Cluster 367942 has duplicate pairs: [367942, 434532]
# Cluster 367950 has duplicate pairs: [367950, 452707, 463031]
# Cluster 369749 has duplicate pairs: [369749, 443064]
# Cluster 370382 has duplicate pairs: [370382, 387337]
# Cluster 370770 has duplicate pairs: [370770, 385876]
# Cluster 370781 has duplicate pairs: [370781, 453033]
# Cluster 372125 has duplicate pairs: [372125, 467236]
# Cluster 372739 has duplicate pairs: [372739, 462979]
# Cluster 374644 has duplicate pairs: [374644, 422917]
# Cluster 374894 has duplicate pairs: [374894, 469365]
# Cluster 376753 has duplicate pairs: [376753, 438692]
# Cluster 378349 has duplicate pairs: [378349, 425810]
# Cluster 378388 has duplicate pairs: [378388, 406679]
# Cluster 378661 has duplicate pairs: [378661, 437156]
# Cluster 379017 has duplicate pairs: [379017, 386764]
# Cluster 379468 has duplicate pairs: [379468, 435302]
# Cluster 379917 has duplicate pairs: [379917, 424486]
# Cluster 380570 has duplicate pairs: [380570, 434863]
# Cluster 381133 has duplicate pairs: [381133, 415038, 426674, 447167]
# Cluster 381641 has duplicate pairs: [381641, 404175]
# Cluster 383507 has duplicate pairs: [383507, 430666]
# Cluster 383622 has duplicate pairs: [383622, 429924]
# Cluster 383743 has duplicate pairs: [383743, 438417]
# Cluster 383886 has duplicate pairs: [383886, 405934]
# Cluster 385887 has duplicate pairs: [385887, 439842]
# Cluster 386298 has duplicate pairs: [386298, 433657]
# Cluster 388866 has duplicate pairs: [388866, 434406]
# Cluster 389343 has duplicate pairs: [389343, 439933]
# Cluster 389960 has duplicate pairs: [389960, 412502]
# Cluster 390215 has duplicate pairs: [390215, 395356]
# Cluster 390646 has duplicate pairs: [390646, 413400]
# Cluster 391080 has duplicate pairs: [391080, 405898]
# Cluster 391342 has duplicate pairs: [391342, 442719]
# Cluster 393756 has duplicate pairs: [393756, 468950]
# Cluster 394869 has duplicate pairs: [394869, 458497]
# Cluster 395332 has duplicate pairs: [395332, 462763]
# Cluster 395875 has duplicate pairs: [395875, 439612]
# Cluster 396144 has duplicate pairs: [396144, 418209]
# Cluster 397613 has duplicate pairs: [397613, 456595]
# Cluster 398535 has duplicate pairs: [398535, 428838]
# Cluster 399029 has duplicate pairs: [399029, 419264]
# Cluster 399970 has duplicate pairs: [399970, 426063]
# Cluster 400230 has duplicate pairs: [400230, 435599]
# Cluster 402301 has duplicate pairs: [402301, 435074]
# Cluster 402798 has duplicate pairs: [402798, 429524]
# Cluster 402840 has duplicate pairs: [402840, 437856]
# Cluster 403397 has duplicate pairs: [403397, 461157]
# Cluster 403473 has duplicate pairs: [403473, 416140]
# Cluster 404177 has duplicate pairs: [404177, 407585]
# Cluster 404883 has duplicate pairs: [404883, 442356, 447611]
# Cluster 405659 has duplicate pairs: [405659, 449445]
# Cluster 405989 has duplicate pairs: [405989, 422691]
# Cluster 408061 has duplicate pairs: [408061, 432718]
# Cluster 410475 has duplicate pairs: [410475, 471078]
# Cluster 410637 has duplicate pairs: [410637, 433296]
# Cluster 411729 has duplicate pairs: [411729, 430370]
# Cluster 411828 has duplicate pairs: [411828, 447762]
# Cluster 414673 has duplicate pairs: [414673, 468283]
# Cluster 415842 has duplicate pairs: [415842, 421926]
# Cluster 417029 has duplicate pairs: [417029, 470821]
# Cluster 418826 has duplicate pairs: [418826, 469211]
# Cluster 419870 has duplicate pairs: [419870, 442612]
# Cluster 421426 has duplicate pairs: [421426, 441047]
# Cluster 421618 has duplicate pairs: [421618, 441804]
# Cluster 422695 has duplicate pairs: [422695, 465523]
# Cluster 423125 has duplicate pairs: [423125, 458938]
# Cluster 423665 has duplicate pairs: [423665, 449133]
# Cluster 427319 has duplicate pairs: [427319, 468578]
# Cluster 429119 has duplicate pairs: [429119, 463016]
# Cluster 430615 has duplicate pairs: [430615, 463128]
# Cluster 433689 has duplicate pairs: [433689, 451007]
# Cluster 435088 has duplicate pairs: [435088, 453933]
# Cluster 439720 has duplicate pairs: [439720, 467587]
# Cluster 439857 has duplicate pairs: [439857, 440101]
# Cluster 441795 has duplicate pairs: [441795, 465725]
# Cluster 442630 has duplicate pairs: [442630, 459737]
# Cluster 444279 has duplicate pairs: [444279, 472961]
# Cluster 446142 has duplicate pairs: [446142, 473419]
# Cluster 455480 has duplicate pairs: [455480, 455712]
# Cluster 460380 has duplicate pairs: [460380, 466500]
# Cluster 460900 has duplicate pairs: [460900, 462967]
# Cluster 471652 has duplicate pairs: [471652, 472302]
# [08/11/23 05:57:47] INFO     Loading                         :    ]8;id=359138;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=846231;file:///home/ubuntu/aisyah/text_dedup/minhash.py#332\332]8;;\
#                              0.01s
#                     INFO     MinHashing                      :    ]8;id=512462;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=179062;file:///home/ubuntu/aisyah/text_dedup/minhash.py#332\332]8;;\
#                              28.58s
#                     INFO     Clustering                      :    ]8;id=360008;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=452419;file:///home/ubuntu/aisyah/text_dedup/minhash.py#332\332]8;;\
#                              5.92s
#                     INFO     Filtering                       :    ]8;id=486824;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=430013;file:///home/ubuntu/aisyah/text_dedup/minhash.py#332\332]8;;\
#                              12.29s
#                     INFO     Saving                          :    ]8;id=767925;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=13190;file:///home/ubuntu/aisyah/text_dedup/minhash.py#332\332]8;;\
#                              4.66s
#                     INFO     Cleaning                        :    ]8;id=890288;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=451629;file:///home/ubuntu/aisyah/text_dedup/minhash.py#332\332]8;;\
#                              0.05s
#                     INFO     Total                           :    ]8;id=610246;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=254373;file:///home/ubuntu/aisyah/text_dedup/minhash.py#332\332]8;;\
#                              51.51s
#                     INFO     Before                          :    ]8;id=60970;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=784956;file:///home/ubuntu/aisyah/text_dedup/minhash.py#334\334]8;;\
#                              473487
#                     INFO     After                           :    ]8;id=594205;file:///home/ubuntu/aisyah/text_dedup/minhash.py\minhash.py]8;;\:]8;id=613396;file:///home/ubuntu/aisyah/text_dedup/minhash.py#335\335]8;;\
#                              472816

# %% [markdown]
# The script produced the following
#
# - duplicates.csv : containing duplicate pairs indices (document index)
# - duplicate_cluster.csv: the text of duplicate pairs for view
# - the deduped dataset in huggingface dataset type (from output argument)

# %% [markdown]
# ## View Result

# %%
import pandas as pd

# %%
df = pd.read_csv('output/duplicates.csv')

# %%
df.head(50)
# Out:
#     Cluster  Duplicate Pair
# 0       126   [126, 470431]
# 1       195   [195, 450632]
# 2       484   [484, 448413]
# 3       746   [746, 367517]
# 4      1014  [1014, 344772]
# 5      1294  [1294, 468601]
# 6      1296  [1296, 315917]
# 7      1298  [1298, 462415]
# 8      1337  [1337, 433726]
# 9      1486  [1486, 396912]
# 10     1787  [1787, 457257]
# 11     1794  [1794, 358727]
# 12     1822  [1822, 409252]
# 13     1998  [1998, 322529]
# 14     2105  [2105, 417868]
# 15     2143  [2143, 385378]
# 16     2333  [2333, 301327]
# 17     2353  [2353, 453168]
# 18     3002  [3002, 303473]
# 19     3043  [3043, 443233]
# 20     3124  [3124, 357290]
# 21     3139  [3139, 345280]
# 22     3183  [3183, 447743]
# 23     3258  [3258, 442708]
# 24     3416  [3416, 336660]
# 25     4087  [4087, 357938]
# 26     4151  [4151, 448060]
# 27     4189    [4189, 4867]
# 28     4688  [4688, 303191]
# 29     4902  [4902, 322491]
# 30     5162  [5162, 412475]
# 31     5426  [5426, 407733]
# 32     5901  [5901, 419331]
# 33     6006  [6006, 435005]
# 34     6040  [6040, 374774]
# 35     6150  [6150, 440755]
# 36     6269  [6269, 439609]
# 37     6662  [6662, 357667]
# 38     6832  [6832, 404252]
# 39     6879  [6879, 396837]
# 40     7115  [7115, 343693]
# 41     7279  [7279, 362800]
# 42     7307  [7307, 425938]
# 43     7396  [7396, 312175]
# 44     7700  [7700, 330291]
# 45     7997  [7997, 469016]
# 46     8098  [8098, 333761]
# 47     8726  [8726, 376008]
# 48     8943  [8943, 319472]
# 49     9265  [9265, 402953]

# %%
from datasets import load_from_disk

# Load the dataset from the saved directory
base_ds = load_from_disk("text_dedup/test-1")

# %%
base_ds[126]
# Out:
# {'id': 126,
#  'text': 'PERIKATAN Nasional (PN) Johor hari ini mengesahkan tiada perbincangan mengenai pertukaran mana-mana calon termasuk calon kerusi Parlimen Pulai pada Pilihan Raya Umum ke-15 (PRU15), kata Pengarah Jabatan Pilihan Raya PN Negeri Johor Rasman Ithnain. Beliau berkata setakat ini perbincangan antara parti komponen dalam PN mengenai pemilihan calon berjalan lancar tanpa ada selisih faham atau kecil hati. “Setakat hari ini, PN tak dengar pun ada pertukaran. Kita pun baru dengar (berita ini). Memang tiada perbincangan. Itu hanya khabar angin, (saya rasa) cuma provokasi (pihak lain). “Setakat ini, nama yang ada di tangan saya, (masih) nama Deepak (Jaikishan Rewachand) (untuk kerusi Pulai),” katanya kepada pemberita di Bilik Gerakan Utama PN Negeri Johor di Kulai hari ini. Rasman berkata demikian ketika mengulas laporan sebuah akhbar tempatan berbahasa Inggeris semalam, yang memetik Pengerusi Gerakan Johor Teo Kok Chee sebagai berkata Presiden Gerakan Dominic Lau menamakan calon lain untuk bertanding di kerusi Parlimen Pulai atas tiket Gerakan. Menurut Teo keputusan menukar calon berkenaan dibuat selepas pengumuman oleh Pengerusi PN Muhyiddin Yassin dua hari lepas. Mengenai sama ada terdapat calon daripada parti lain yang cuba memancing kerusi menerusi PN seperti berlaku di Perlis, Rasman berkata sebarang keputusan akan diserahkan di peringkat pusat. PN Perlis dilaporkan mengesahkan memberi laluan kepada penyandang kerusi Arau Shahidan Kassim untuk mewakili gabungan tersebut di Parlimen itu pada PRU15. – Bernama, 3 November, 2022.'}

# %%
base_ds[470431]
# Out:
# {'id': 470431,
#  'text': 'Perikatan Nasional (PN) Johor hari ini mengesahkan tiada perbincangan mengenai pertukaran mana-mana calon termasuk calon kerusi parlimen Pulai pada Pilihan Raya Umum ke-15 (PRU15), kata Pengarah Jabatan Pilihan Raya PN Negeri Johor Rasman Ithnain. Beliau berkata setakat ini perbincangan antara parti komponen dalam PN mengenai pemilihan calon berjalan lancar tanpa ada selisih faham atau kecil hati. “Setakat hari ini, PN tak dengar pun ada pertukaran. Kita pun baru dengar (berita ini). Memang tiada perbincangan. Itu hanya khabar angin, (saya rasa) cuma provokasi (pihak lain). “Setakat ini, nama yang ada di tangan saya, (masih) nama Deepak (Jaikishan Rewachand) (untuk kerusi Pulai),” katanya kepada pemberita di Bilik Gerakan Utama PN Negeri Johor hari ini. Rasman berkata demikian ketika mengulas laporan sebuah akhbar tempatan berbahasa Inggeris semalam, yang memetik Pengerusi Gerakan Johor Teo Kok Chee sebagai berkata Presiden Gerakan Dominic Lau menamakan calon lain untuk bertanding di kerusi Parlimen Pulai atas tiket Gerakan. Menurut Teo keputusan menukar calon berkenaan dibuat selepas pengumuman oleh Pengerusi PN Muhyiddin Yassin dua hari lepas. Mengenai sama ada terdapat calon daripada parti lain yang cuba memancing kerusi menerusi PN seperti berlaku di Perlis, Rasman berkata sebarang keputusan akan diserahkan di peringkat pusat. PN Perlis dilaporkan mengesahkan memberi laluan kepada penyandang kerusi Arau Shahidan Kassim untuk mewakili gabungan tersebut di Parlimen itu pada PRU15. - Bernama Bernama'}

# %%
""" Dedup Dataset """
dedup_ds = load_from_disk("MinHash_Output/Dedup_Dataset_Trial-0")

# %%
# Extract IDs from the datasets
base_df_id = set(base_ds['id'])
dedup_df_id = set(dedup_ds['id'])

# Find IDs that do not exist in dataset2
missing_ids = base_df_id - dedup_df_id

# %%
base_df = base_ds.to_pandas()
dedup_df = dedup_ds.to_pandas()

# %%
dedup_df
# Out:
#             id                                               text
# 0            0  SELEPAS seminggu politik negara kecoh pada Feb...
# 1            1  PARLIMEN perlu meluluskan undang-undang bagi m...
# 2            2  MISTERI kehilangan seorang warga emas berusia ...
# 3            3  LIMPAHAN air Sungai Muar yang berlaku sejak se...
# 4            4  POLIS Kelantan telah mengenal pasti 28 lokasi ...
# ...        ...                                                ...
# 472811  473482  \nKhabar angin bertiup kencang di kalangan pem...
# 472812  473483  \nKira-kira dua juta daripada tujuh juta pener...
# 472813  473484  \nPerairan Sabah didapati bebas daripada kenai...
# 472814  473485  \nPerbicaraan ke atas bekas pengurus besar Lem...
# 472815  473486  Gempa bumi berukuran 6.1 pada skala Richter me...
#
# [472816 rows x 2 columns]

# %%
len(dedup_df)
# Out:
# 472816
