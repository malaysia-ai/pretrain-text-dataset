# %%
from glob import glob
from streaming import MDSWriter
from streaming import LocalDataset
from transformers import default_data_collator, DataCollatorForLanguageModeling
from tqdm import tqdm
import numpy as np

# %%
folders = sorted(glob('tokenized_indexes/tokenized-*'), key = lambda x: int(x.split('-')[-1]))

# %%
folders
# Out:
# ['tokenized_indexes/tokenized-0',
#  'tokenized_indexes/tokenized-1',
#  'tokenized_indexes/tokenized-2',
#  'tokenized_indexes/tokenized-3',
#  'tokenized_indexes/tokenized-4',
#  'tokenized_indexes/tokenized-5',
#  'tokenized_indexes/tokenized-6',
#  'tokenized_indexes/tokenized-7',
#  'tokenized_indexes/tokenized-8',
#  'tokenized_indexes/tokenized-9',
#  'tokenized_indexes/tokenized-10',
#  'tokenized_indexes/tokenized-11',
#  'tokenized_indexes/tokenized-12']

# %%
from streaming.base.format.mds.encodings import Encoding, _encodings

class UInt16(Encoding):
    def encode(self, obj) -> bytes:
        return obj.tobytes()

    def decode(self, data: bytes):
        return np.frombuffer(data, np.uint16)

_encodings['uint16'] = UInt16

# %%
columns = {
    'input_ids': 'uint16',
}

compression = 'zstd'
hashes = 'sha1', 'xxh64'

# %%
# !rm -rf combine-all

# %%
with MDSWriter(out='combine-all', columns=columns, compression=None, hashes=hashes) as out:
    for f in folders:
        try:
            dataset = LocalDataset(local=f)
            for i in tqdm(range(len(dataset))):
                out.write(dataset[i])
        except Exception as e:
            print(e)
            pass
# Out:
# 100%|██████████| 917963/917963 [00:44<00:00, 20796.81it/s]
# 100%|██████████| 77395/77395 [00:06<00:00, 12001.85it/s]
# 100%|██████████| 78232/78232 [00:03<00:00, 23822.57it/s]
# 100%|██████████| 78239/78239 [00:06<00:00, 11667.44it/s]
# 100%|██████████| 78388/78388 [00:09<00:00, 7949.49it/s]
# 100%|██████████| 78370/78370 [00:04<00:00, 19453.48it/s]
# 100%|██████████| 78304/78304 [00:10<00:00, 7511.84it/s]
# 100%|██████████| 78044/78044 [00:07<00:00, 10382.35it/s]
# 100%|██████████| 226206/226206 [00:24<00:00, 9398.62it/s]
# 100%|██████████| 391726/391726 [00:30<00:00, 13022.95it/s]
# 100%|██████████| 105720/105720 [00:09<00:00, 11343.67it/s]
# 100%|██████████| 530659/530659 [00:37<00:00, 14269.17it/s]
# 100%|██████████| 409162/409162 [00:30<00:00, 13255.96it/s]

# %%
# !ls -lh combine-all
# Out:
# total 24G
# -rw-r--r-- 1 ubuntu ubuntu 145K Dec 28 10:28 index.json
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00000.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00001.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00002.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00003.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00004.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00005.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00006.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00007.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00008.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00009.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00010.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00011.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00012.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00013.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00014.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00015.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00016.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00017.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00018.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00019.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00020.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00021.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00022.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00023.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00024.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00025.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00026.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00027.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00028.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00029.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00030.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00031.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00032.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00033.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00034.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00035.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00036.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00037.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00038.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00039.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00040.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00041.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:24 shard.00042.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00043.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00044.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00045.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00046.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00047.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00048.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00049.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00050.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00051.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00052.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00053.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00054.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00055.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00056.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00057.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00058.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00059.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00060.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00061.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00062.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00063.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00064.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00065.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00066.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00067.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00068.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00069.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00070.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00071.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00072.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00073.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00074.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00075.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00076.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00077.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00078.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00079.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00080.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00081.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00082.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00083.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00084.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00085.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00086.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00087.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00088.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00089.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00090.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00091.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00092.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00093.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00094.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00095.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00096.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00097.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00098.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00099.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00100.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00101.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00102.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00103.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00104.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00105.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00106.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00107.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00108.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00109.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00110.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00111.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00112.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00113.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00114.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00115.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00116.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00117.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00118.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00119.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00120.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00121.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00122.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00123.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00124.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00125.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00126.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00127.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00128.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00129.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00130.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00131.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00132.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00133.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00134.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00135.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00136.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00137.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00138.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00139.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00140.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00141.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00142.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00143.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00144.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00145.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00146.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00147.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00148.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00149.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00150.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00151.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00152.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00153.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00154.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00155.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00156.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00157.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:25 shard.00158.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00159.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00160.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00161.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00162.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00163.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00164.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00165.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00166.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00167.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00168.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00169.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00170.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00171.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00172.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00173.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00174.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00175.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00176.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00177.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00178.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00179.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00180.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00181.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00182.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00183.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00184.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00185.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00186.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00187.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00188.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00189.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00190.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00191.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00192.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00193.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00194.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00195.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00196.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00197.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00198.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00199.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00200.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00201.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00202.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00203.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00204.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00205.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00206.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00207.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00208.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00209.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00210.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00211.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00212.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00213.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00214.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00215.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00216.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00217.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00218.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00219.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00220.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00221.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00222.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00223.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00224.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00225.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00226.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00227.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00228.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00229.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00230.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00231.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00232.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00233.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00234.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:26 shard.00235.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00236.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00237.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00238.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00239.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00240.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00241.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00242.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00243.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00244.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00245.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00246.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00247.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00248.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00249.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00250.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00251.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00252.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00253.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00254.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00255.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00256.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00257.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00258.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00259.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00260.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00261.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00262.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00263.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00264.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00265.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00266.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00267.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00268.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00269.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00270.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00271.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00272.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00273.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00274.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00275.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00276.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00277.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00278.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00279.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00280.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00281.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00282.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00283.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00284.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00285.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00286.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00287.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00288.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00289.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00290.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00291.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00292.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00293.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00294.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00295.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00296.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00297.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00298.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00299.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00300.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00301.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00302.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00303.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00304.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00305.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00306.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00307.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00308.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00309.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00310.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00311.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00312.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00313.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00314.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00315.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00316.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00317.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00318.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00319.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00320.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00321.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00322.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00323.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00324.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00325.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00326.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00327.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00328.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00329.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00330.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00331.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00332.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:27 shard.00333.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00334.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00335.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00336.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00337.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00338.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00339.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00340.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00341.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00342.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00343.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00344.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00345.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00346.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00347.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00348.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00349.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00350.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00351.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00352.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00353.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00354.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00355.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00356.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00357.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00358.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00359.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00360.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00361.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00362.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00363.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00364.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00365.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00366.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00367.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00368.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00369.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00370.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00371.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00372.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00373.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00374.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00375.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00376.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00377.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00378.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00379.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00380.mds
# -rw-r--r-- 1 ubuntu ubuntu  64M Dec 28 10:28 shard.00381.mds
# -rw-r--r-- 1 ubuntu ubuntu  20M Dec 28 10:28 shard.00382.mds

# %%
dataset = LocalDataset(local='combine-all')

# %%
(len(dataset) * 4096) / 1e9
# Out:
# 12.813959168

# %%
# !git clone https://huggingface.co/datasets/malaysia-ai/mosaic-solar
# !cp combine-all/* mosaic-solar
# Out:
# Cloning into 'mosaic-solar'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3
# Unpacking objects: 100% (3/3), 516 bytes | 516.00 KiB/s, done.
