# %%
from glob import glob
from tqdm import tqdm
from transformers import AutoTokenizer
import json

# %%
files = glob('hf-datasets/dedupe-datasets/*.jsonl')
len(files)
# Out:
# 55

# %%
tokenizer = AutoTokenizer.from_pretrained('meta-llama/Llama-2-13b-hf')

# %%
# !wget https://gist.githubusercontent.com/huseinzol05/98974ae8c6c7a65d4bc0af9f5003786a/raw/5aa5257608b61e8fcc828e99fbd070d5ca7358e3/mp.py

# %%
import mp

# %%
def loop(texts):
    texts, _ = texts
    tokenizer = AutoTokenizer.from_pretrained('meta-llama/Llama-2-13b-hf')
    count = 0
    for t in tqdm(texts):
        try:
            t = json.loads(l)
            if isinstance(t, dict):
                if 'text' in t:
                    t = t['text']
                elif 'headline' in t and 'text' in t:
                    t = t['headline'] + ' ' + t['text']
            count += len(tokenizer.tokenize(t))
        except:
            pass
    return [count]

# %%
sum(mp.multiprocessing(texts, loop, cores = 12))
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
counts = {}

for f in files:
    
    texts = []
    with open(f) as fopen:
        for l in fopen:
            texts.append(l)
    
    counts[f] = sum(mp.multiprocessing(texts, loop, cores = 12))
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
with open('count.json', 'w') as fopen:
    json.dump(counts, fopen)

# %%
sum(counts.values())
# Out:
# 3297709834
