# %%
# !git lfs clone https://huggingface.co/datasets/malaysia-ai/dedup-text-dataset

# %%
import json
import os
from glob import glob
from tqdm import tqdm

# %%
def partition(text, size = 500):
    splitted = text.split()
    return [' '.join(splitted[i: i + size]) for i in range(0, len(splitted), size)]

# %%
a = open('prepare-dedup-text-dataset.jsonl', 'w')

# %%
dedup_text_dataset = glob('dedup-text-dataset/*.jsonl')
for f in dedup_text_dataset:
    with open(f) as fopen:
        for l in tqdm(fopen):
            try:
                data = '<s>' + json.loads(l) + '</s>'
                partitioned = partition(data)
                for p in partitioned:
                    data = {
                        'text': p,
                    }
                    a.write(f'{json.dumps(data)}\n')
                    a.flush()
            except Exception as e:
                print(e)
                pass
# Out:
# 233it [00:00, 600.47it/s]
# 47it [00:00, 1065.37it/s]
# 8447it [00:14, 597.36it/s]
# 937it [00:01, 625.38it/s]
# 48401it [00:15, 3205.06it/s]
# 32085it [00:27, 1182.64it/s]
# 839it [00:01, 805.30it/s]
# 16443it [00:16, 1000.42it/s]
# 13101it [00:06, 2047.95it/s]
# 112it [00:00, 2298.51it/s]
# 1171628it [16:02, 1217.39it/s]
# 51691it [00:13, 3708.23it/s]
# 45326it [00:26, 1734.38it/s]
# 362221it [06:12, 971.18it/s]
# 66212it [00:26, 2486.23it/s]
# 24411it [00:20, 1173.52it/s]
# 3625it [00:05, 607.47it/s]
# 1578it [00:00, 41148.24it/s]
# 43it [00:00, 2938.38it/s]
# 74it [00:00, 1784.52it/s]
# 1092497it [00:47, 23223.99it/s]
# 4702it [00:05, 913.08it/s]
# 68it [00:00, 2454.16it/s]
# 42143it [00:11, 3553.89it/s]
# 341it [00:00, 1143.75it/s]
# 53158it [00:08, 6108.97it/s]
# 1140it [00:00, 2748.16it/s]
# 298it [00:01, 252.35it/s]
# 31505765it [13:50, 37938.02it/s]
# 11439it [00:01, 6655.11it/s]
# 5550it [00:00, 21058.10it/s]
# 10483it [00:02, 3796.73it/s]
# 40it [00:00, 4568.21it/s]
# ...
